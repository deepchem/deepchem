# %% [markdown]
# This notebook walks through the creation of multitask models on MUV. The goal is to demonstrate that multitask methods outperform singletask methods on MUV.

# %%
# %reload_ext autoreload
# %autoreload 2
# %pdb off
reload = True
# Out:
# Automatic pdb calling has been turned OFF

# %%
from deepchem.utils.save import load_from_disk
from deepchem.datasets import Dataset

dataset_file= "../datasets/muv.csv.gz"
dataset = load_from_disk(dataset_file)
print("Columns of dataset: %s" % str(dataset.columns.values))
print("Number of examples in dataset: %s" % str(dataset.shape[0]))
# Out:
# Columns of dataset: ['mol_id' 'smiles' 'MUV-692' 'MUV-689' 'MUV-846' 'MUV-859' 'MUV-644'
#  'MUV-548' 'MUV-852' 'MUV-600' 'MUV-810' 'MUV-712' 'MUV-737' 'MUV-858'
#  'MUV-713' 'MUV-733' 'MUV-652' 'MUV-466' 'MUV-832']
# Number of examples in dataset: 93127

# %% [markdown]
# Now, let's visualize some compounds from our dataset

# %%
from itertools import islice
from rdkit import Chem
from deepchem.utils.visualization import mols_to_pngs
from deepchem.utils.visualization import display_images

num_to_display = 12
molecules = []
for _, data in islice(dataset.iterrows(), num_to_display):
    molecules.append(Chem.MolFromSmiles(data["smiles"]))
display_images(mols_to_pngs(molecules))
# Out:
# <img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test0.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test1.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test10.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test11.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test2.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test3.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test4.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test5.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test6.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test7.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test8.png' /><img style='width: 140px; margin: 0px; float: left; border: 1px solid black;' src='test9.png' />

# %%
from deepchem.featurizers.fingerprints import CircularFingerprint

featurizers = [CircularFingerprint(size=1024)]

# %%
MUV_tasks = ['MUV-692', 'MUV-689', 'MUV-846', 'MUV-859', 'MUV-644',
             'MUV-548', 'MUV-852', 'MUV-600', 'MUV-810', 'MUV-712',
             'MUV-737', 'MUV-858', 'MUV-713', 'MUV-733', 'MUV-652',
             'MUV-466', 'MUV-832']

# %%
import os
from deepchem.featurizers.featurize import DataFeaturizer

# The base_dir holds the results of all analysis
base_dir = "/scratch/users/rbharath/muv_multitask_analysis"
#Make directories to store the raw and featurized datasets.
feature_dir = os.path.join(base_dir, "features")
samples_dir = os.path.join(base_dir, "samples")

featurizer = DataFeaturizer(tasks=MUV_tasks,
                            smiles_field="smiles",
                            compound_featurizers=featurizers,
                            verbosity="low")

# Setting reload=True directs the featurizer to use existing featurization on disk if such exists.
featurized_samples = featurizer.featurize(dataset_file, feature_dir, samples_dir, shard_size=4096,
                                          reload=reload)

# %%
splittype = "scaffold"
train_dir = os.path.join(base_dir, "train_dataset")
valid_dir = os.path.join(base_dir, "valid_dataset")
test_dir = os.path.join(base_dir, "test_dataset")

train_samples, valid_samples, test_samples = featurized_samples.train_valid_test_split(
    splittype, train_dir, valid_dir, test_dir, log_every_n=1000, reload=reload)
# Out:
# FeaturizedSamples.train_valid_test_split
# dataset_files
# [u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard0.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard1.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard2.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard3.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard4.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard5.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard6.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard7.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard8.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard9.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard10.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard11.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard12.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard13.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard14.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard15.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard16.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard17.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard18.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard19.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard20.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard21.joblib', u'/scratch/users/rbharath/muv_multitask_analysis/features/features_shard22.joblib']

# %%
from deepchem.datasets import Dataset
print("Creating train dataset")
train_dataset = Dataset(data_dir=train_dir, samples=train_samples, 
                        featurizers=featurizers, tasks=MUV_tasks,
                        verbosity="low", reload=reload)
print("Creating valid dataset")
valid_dataset = Dataset(data_dir=valid_dir, samples=valid_samples, 
                        featurizers=featurizers, tasks=MUV_tasks,
                        verbosity="low", reload=reload)
print("Creating test dataset")
test_dataset = Dataset(data_dir=test_dir, samples=test_samples, 
                       featurizers=featurizers, tasks=MUV_tasks,
                       verbosity="low", reload=reload)
# Out:
# Creating train dataset
# Creating valid dataset
# Creating test dataset

# %%
input_transformers = []
output_transformers = []

# %%
from deepchem.hyperparameters import HyperparamOpt
from deepchem.models.tensorflow_models.fcnet import TensorflowMultiTaskClassifier
import numpy.random
model_dir = os.path.join(base_dir, "model")

MUV_task_types = {task: "Classification" for task in MUV_tasks}
params_dict = {"activation": ["relu"],
                "momentum": [.9],
                "batch_size": [50],
                "init": ["glorot_uniform"],
                "data_shape": [train_dataset.get_data_shape()],
                "learning_rate": [1e-3], #np.power(10., np.random.uniform(-5, -2, size=5)),
                "decay": [1e-6], #np.power(10, np.random.uniform(-6, -4, size=5)),
                "nb_hidden": [1000], # TODO(rbharath): replace this with layer_sizes
                "nb_epoch": [1],
                "nesterov": [False],
                "dropouts": [[.5]],
                "nb_layers": [1],
                "batchnorm": [False],
                "layer_sizes": [[1000]],
                "weight_init_stddevs": [[.1]],
                "bias_init_consts": [[1.]],
                "num_classes": [2],
                "penalty": [0.], # TODO(rbharath): Should be weight decay
                "optimizer": ["sgd"],
                "num_classification_tasks": [len(MUV_task_types)]
              }

optimizer = HyperparamOpt(TensorflowMultiTaskClassifier, MUV_task_types)
best_dnn, best_hyperparams, all_results = optimizer.hyperparam_search(
    params_dict, train_dataset, valid_dataset, output_transformers, logdir=model_dir,
    metric="roc_auc_score")
# Out:
# is_training()
# train
# [True]
# is_training()
# train
# [True]
# TensorflowClassiifer.add_weight_placeholders
# self.weights
# [<tf.Tensor 'placeholders/Identity_17:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_18:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_19:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_20:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_21:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_22:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_23:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_24:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_25:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_26:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_27:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_28:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_29:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_30:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_31:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_32:0' shape=(50,) dtype=float32>, <tf.Tensor 'placeholders/Identity_33:0' shape=(50,) dtype=float32>]
# len(dataset)
# 93127
# batch_size
# 50
# Iterating on shard-1/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-2/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-2/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-3/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-3/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-4/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-4/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-5/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-5/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-6/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-6/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-7/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-7/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-8/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-8/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# ...
# Iterating on batch-79/shard-21/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-21/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-21/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-22/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-22/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-23/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# Iterating on batch-2/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-3/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-4/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-5/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-6/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-7/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-8/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-9/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-10/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-11/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-12/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-13/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-14/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-15/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-16/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-17/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-18/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-19/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-20/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-21/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-22/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-23/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-24/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-25/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-26/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-27/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-28/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-29/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-30/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-31/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-32/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-33/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-34/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-35/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-36/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-37/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-38/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-39/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-40/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-41/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-42/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-43/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-44/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-45/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-46/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-47/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-48/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-49/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-50/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-51/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-52/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-53/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-54/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-55/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-56/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-57/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-58/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-59/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-60/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-61/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-62/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-63/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-64/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-65/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-66/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-67/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-68/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-69/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-70/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-71/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-72/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-73/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-74/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-75/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-76/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-77/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-78/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-79/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-80/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on batch-81/shard-23/epoch-2
# _pad_batch
# np.shape(X_b)
# (50, 1024)
# Iterating on shard-1/epoch-2
# np.shape(X)
# (4049, 1024)
# np.shape(y)
# (4049, 17)
# np.shape(w)
# (4049, 17)
# interval_points
# [   0   49   99  149  199  249  299  349  399  449  499  549  599  649  699
#   749  799  849  899  949  999 1049 1099 1149 1199 1249 1299 1349 1399 1449
#  1499 1549 1599 1649 1699 1749 1799 1849 1899 1949 1999 2049 2099 2149 2199
#  2249 2299 2349 2399 2449 2499 2549 2599 2649 2699 2749 2799 2849 2899 2949
#  2999 3049 3099 3149 3199 3249 3299 3349 3399 3449 3499 3549 3599 3649 3699
#  3749 3799 3849 3899 3949 3999 4049]
# Iterating on batch-1/shard-1/epoch-2
# _pad_batch
# np.shape(X_b)
# (49, 1024)
# is_training()
# train
# [True]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-9189819c8285> in <module>()
#      30 best_dnn, best_hyperparams, all_results = optimizer.hyperparam_search(
#      31     params_dict, train_dataset, valid_dataset, output_transformers, logdir=model_dir,
# ---> 32     metric="roc_auc_score")
#
# /home/rbharath/deepchem/deepchem/hyperparameters/__init__.pyc in hyperparam_search(self, params_dict, train_dataset, valid_dataset, output_transformers, metric, use_max, verbosity, logdir)
#      56       evaluator = Evaluator(model, valid_dataset, output_transformers)
#      57       df, score = evaluator.compute_model_performance(
# ---> 58           valid_csv_out, valid_stats_out)
#      59       valid_score = score.iloc[0][metric]
#      60       all_scores[hyperparameter_tuple] = valid_score
#
# /home/rbharath/deepchem/deepchem/utils/evaluate.pyc in compute_model_performance(self, csv_out, stats_file, threshold)
#      86     Computes statistics of model on test data and saves results to csv.
#      87     """
# ---> 88     pred_y_df = self.model.predict(self.dataset, self.transformers)
#      89
#      90     task_type = self.task_type
#
# /home/rbharath/deepchem/deepchem/models/__init__.pyc in predict(self, dataset, transformers)
#     124     batch_size = self.model_params["batch_size"]
#     125     for (X_batch, y_batch, w_batch, ids_batch) in dataset.iterbatches(batch_size):
# --> 126       y_pred = self.predict_on_batch(X_batch)
#     127       print("predict()")
#     128       print("y_pred.shape")
#
# /home/rbharath/deepchem/deepchem/models/tensorflow_models/__init__.py in predict_on_batch(self, X)
#     559     """
#     560     with self.graph.as_default():
# --> 561       assert not model_ops.is_training()
#     562       assert self._restored_model
#     563       self.require_attributes(['output', 'labels', 'weights'])
#
# AssertionError:
